# %%
from ufal.udpipe import Model, Pipeline
from collections import defaultdict, Counter
from math import log

import conllu
import pandas as pd

# %%
def process(text):
    model = Model.load("russian-syntagrus-ud-2.4-190531.udpipe")
    pipeline = Pipeline(model, 'tokenize', Pipeline.DEFAULT, Pipeline.DEFAULT, 'conllu')
    return pipeline.process(text)

# %%
def txt_to_conllu(fn):
    with open (fn, 'r', encoding='utf-8') as inp:
        return process(inp.read())

# %%
def LLR(freq_ab, freq_a, freq_b, N):
    '''Log-Likelihood Ratio'''
    a = freq_ab
    b = freq_a -freq_ab
    c = freq_b
    d = N - freq_b
    E1 = c * (a+b)/(c+d)
    E2 = d * (a+b)/(c+d)
    return 2*((a*log(a/E1)) + (b*log(b/E2)))

def PMI(freq_ab, freq_a, freq_b, N):
    '''Pointwise Mutual Information'''
    p_xy = freq_ab / N
    p_x = freq_a / N
    p_y = freq_b / N
    return log(p_xy/(p_x * p_y), 2)

def Dice(freq_ab, freq_a, freq_b):
    '''Dice coefficient'''
    return 2*(freq_ab)/(freq_a + freq_b)

# %%
def get_colloc_freqs(fn, tag1='VERB', tag2 = 'NOUN', deprel='obj', freq_filter1=50, freq_filter2=1):
    ddict1 = defaultdict(int)
    ddict2 = defaultdict(int)
    conllu_str = txt_to_conllu(fn)
    parsed_text = conllu.parse(conllu_str)
    
    N = 0
    
    for sent in parsed_text:
        for token in sent:
            N += 1
            if token["upostag"] == tag1:
                ddict1[token["lemma"]] += 1
            elif token["upostag"] == tag2:
                ddict2[token["lemma"]] += 1
    
    collocs = []
    output = []
    
    for sent in parsed_text:
        for token in sent:
            if token["upostag"] == tag2 and token["deprel"] == deprel and ddict2[token["lemma"]] >= freq_filter2:
                ## because UDPipe starts counting from 1:
                head_id = token["head"] - 1
                head = sent[head_id]
                if head["upostag"] == tag1 and ddict1[head["lemma"]] >= freq_filter1:
                    reverse_order = False
                    if token["id"] < head_id:
                        reverse_order = True
                    collocs.append((head["lemma"], token["lemma"], reverse_order))
    
    
    collocs = Counter(collocs)
    
    for colloc, colloc_freq in collocs.items():
        word1, word2, reverse_order = colloc
        output.append({
            tag1: word1,
            tag2: word2,
            "colloc_freq": colloc_freq,
            tag1+"_freq": ddict1[word1],
            tag2+"_freq": ddict2[word2],
            "reverse_order": reverse_order,
            "LLR": LLR(colloc_freq, ddict1[word1], ddict2[word2], N),
            "PMI": PMI(colloc_freq, ddict1[word1], ddict2[word2], N),
            "Dice": Dice(colloc_freq, ddict1[word1], ddict2[word2])
        })
    
    return pd.DataFrame(output)

# %%
collocs = get_colloc_freqs("testet2.txt")

# %%
collocs
# Out:
#          Dice         LLR             NOUN  NOUN_freq        PMI  \
# 0    0.206483  641.203839              иск        559   6.555717
# 1    0.071429  107.504732          договор        103   6.237236
# 2    0.076923   62.255987           вопрос        118   6.979693
# 3    0.022388   28.924443      руководство         75   4.861710
# 4    0.043956   36.414686             срок        146   5.760642
# 5    0.004219    4.734877          олигарх         13   4.805126
# 6    0.026667   13.139802        ведомство         45   6.148090
# 7    0.022428  168.855386              суд       3958   3.757270
# 8    0.017699    9.683471        заявление        149   4.868234
# 9    0.016598    8.890000      ходатайство        142   4.575085
# 10   0.007968    3.538002           жалоба        192   3.886584
# 11   0.023810    9.497978              шаг          7   8.280048
# 12   0.014599    5.507443              вид         43   5.373336
# 13   0.022346   11.511821       заключение        118   5.540809
# 14   0.075000   33.597682         согласие         10   9.487940
# 15   0.029412   34.368997           сделка         63   5.531419
# 16   0.020247   21.095907         господин        428   2.934024
# 17   0.082192  101.490332           жалоба        192   6.241489
# 18   0.063241   56.164379    постановление        100   6.452945
# 19   0.012500    5.434159             доля         33   5.321110
# 20   0.169972  252.690411         приговор        200   7.359836
# 21   0.098299  349.381285          решение        907   5.991265
# 22   0.005038    2.684903  ответственность         52   3.223297
# 23   0.140625   89.786431      компенсация         66   8.525524
# 24   0.026490   12.919420          санкция         49   6.067054
# 25   0.063158   50.456295          вердикт         37   7.472310
# 26   0.020305   11.245957        наказание         53   5.456344
# 27   0.041667   22.457022    правомочность          5   9.524466
# 28   0.171429  232.348748      ходатайство        142   7.524701
# 29   0.013072    6.961620            судья        162   3.844414
# ..        ...         ...              ...        ...        ...
# 808  0.020408   10.475032        сотрудник        114   5.163747
# 809  0.011976    5.059946      возможность         40   5.043576
# 810  0.008639   19.602085     Спецназовцев          2   8.505566
# 811  0.016529    9.775188          падение          4   8.483824
# 812  0.016129    8.660111        окружение          7   7.676469
# 813  0.007812    2.949169        претензия        157   3.430212
# 814  0.035088   11.903354          выходец          3  10.014339
# 815  0.009091    3.540845           польза         81   3.895398
# 816  0.005731    7.617664        оккупация          4   6.923737
# 817  0.011976    6.627785       забастовка         15   6.199371
# 818  0.007117    6.966404           заявка          7   6.448802
# 819  0.044776   32.106926         повестка          7   9.143112
# 820  0.000495    0.586192              суд       3958  -0.971406
# 821  0.004310    7.612638          союзник          3   6.920604
# 822  0.017241    5.874829         чиновник         56   5.639944
# 823  0.011905    4.597911    правительство        108   4.692411
# 824  0.008929    3.762789           тысяча        162   4.060143
# 825  0.005556    5.019325           платеж         15   5.016846
# 826  0.009346    4.049608         действие        160   4.277374
# 827  0.026667   11.323954           бойкот          3   9.599302
# 828  0.009302    3.512839       заключение        118   3.871633
# 829  0.008097    3.024356      ходатайство        142   3.490196
# 830  0.028169   13.576202          пощечин          1  11.224906
# 831  0.019048    6.304458         комиссия         45   5.955445
# 832  0.011173    8.186023    вмешательство          6   7.334598
# 833  0.011765    4.919818   доказательство         43   4.939240
# 834  0.011905    4.444308           выборы         91   4.579608
# 835  0.014815    7.489461    политэмигрант         12   6.826712
# 836  0.008639   19.602085   молодогвардеец          2   8.505566
# 837  0.005714    7.175483    правомочность          5   6.601808
#
#               VERB  VERB_freq  colloc_freq  reverse_order
# 0           подать        274           86          False
# 1         признать        345           16          False
# 2      рассмотреть         90            8          False
# 3         обвинить        461            6          False
# 4         получить        127            6          False
# 5         обвинить        461            1          False
# 6        направить        105            2          False
# 7          просить        144           46          False
# 8           делать         77            2           True
# 9    рассматривать         99            2          False
# 10        отказать         59            1          False
# 11          делать         77            1          False
# 12           иметь         94            1          False
# 13        оставить         61            2          False
# 14            дать         70            3          False
# 15        признать        345            6          False
# 16        обвинить        461            9          False
# 17   удовлетворить        173           15          False
# 18         вынести        153            8          False
# 19        получить        127            1          False
# 20         вынести        153           30          False
# 21         принять        151           52          False
# 22        признать        345            1          False
# 23       выплатить         62            9          False
# 24      обжаловать        102            2          False
# 25         вынести        153            6          False
# 26         просить        144            2          False
# 27     подтвердить         91            2          False
# 28   удовлетворить        173           27          False
# 29         просить        144            2          False
# ..             ...        ...          ...            ...
# 808   арестовывать         82            2          False
# 809       получить        127            1          False
# 810       обвинить        461            2           True
# 811     отказаться        117            1           True
# 812     отказаться        117            1           True
# 813  рассматривать         99            1          False
# 814   принадлежать         54            1          False
# 815     обратиться        139            1          False
# 816       признать        345            1          False
# 817        считать        152            1          False
# 818         подать        274            1          False
# 819       получить        127            3          False
# 820       отменить         83            1          False
# 821       обвинить        461            1          False
# 822        обязать         60            1          False
# 823        обязать         60            1          False
# 824      выплатить         62            1          False
# 825       признать        345            1          False
# 826     оспаривать         54            1          False
# 827       объявить         72            1          False
# 828     предъявить         97            1          False
# 829      направить        105            1          False
# 830           дать         70            1          False
# 831        обязать         60            1          False
# 832      требовать        173            1          False
# 833       получить        127            1          False
# 834         делать         77            1          False
# 835    приговорить        123            1          False
# 836       обвинить        461            2          False
# 837       признать        345            1          False
#
# [838 rows x 9 columns]

# %% [markdown]
# Итого - получили 838 коллокаций

# %% [markdown]
# Проранжируем данные по метрикам:

# %%
for col in ('LLR', 'PMI', 'Dice'):
    collocs[col+'_rank'] = collocs[col].rank(method='dense', ascending=False)

# %%
collocs.head()
# Out:
#        Dice         LLR         NOUN  NOUN_freq       PMI         VERB  \
# 0  0.206483  641.203839          иск        559  6.555717       подать
# 1  0.071429  107.504732      договор        103  6.237236     признать
# 2  0.076923   62.255987       вопрос        118  6.979693  рассмотреть
# 3  0.022388   28.924443  руководство         75  4.861710     обвинить
# 4  0.043956   36.414686         срок        146  5.760642     получить
#
#    VERB_freq  colloc_freq  reverse_order  LLR_rank  PMI_rank  Dice_rank
# 0        274           86          False       1.0     214.0        1.0
# 1        345           16          False      15.0     248.0       33.0
# 2         90            8          False      34.0     182.0       29.0
# 3        461            6          False      82.0     423.0      151.0
# 4        127            6          False      59.0     301.0       68.0

# %% [markdown]
# Выделим коллокации, соответствующие "Золотому стандарту":

# %%
gold_stand = collocs[(collocs['LLR_rank'] <= 100) & (collocs['PMI_rank'] <= 100) & (collocs['Dice_rank'] <= 100)]

# %%
gold_stand.shape
# Out:
# (29, 12)

# %% [markdown]
# Всего получилось 29 коллокаций, соответствующих "Золотому стандарту" - попадающих в топ-100 по всем метрикам.

# %% [markdown]
# Откроем словарь глагольной сочетаемости:

# %%
colloc_vocab = []

with open('verb_coll (1).txt', 'r', encoding='utf-8') as inp:
    for line in inp.readlines():
        line = line.strip()
        if line:
            word, feats, colloc = line.split("\t")
            order = feats.split()[-1]
            if order in ("order=VN", "order=NV"):
                if colloc.startswith("(не)"):
                    colloc = colloc[5:]
                reverse_order = False
                try:
                    if order == "order=VN":
                        verb, noun = colloc.split(' ', 1)
                    elif order == "order=NV":
                        noun, verb = colloc.split(' ', 1)
                        reverse_order = True
                    colloc_vocab.append((verb, noun, reverse_order))
                except:
                    # пропускаем коллокации, в которых забыли поставить пробел:
                    pass

colloc_vocab = set(colloc_vocab)

# %%
len(colloc_vocab)
# Out:
# 9564

# %% [markdown]
# Пересечём его с золотым стандартом:

# %%
gold_stand['in_vocab'] = collocs.apply(lambda x: (x["VERB"], x["NOUN"], x["reverse_order"]) in colloc_vocab, axis=1)
intersection = gold_stand[gold_stand['in_vocab'] == True]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
intersection
# Out:
#          Dice        LLR         NOUN  NOUN_freq        PMI      VERB  \
# 14   0.075000  33.597682     согласие         10   9.487940      дать
# 34   0.055556  27.181366        добро          2  11.224906      дать
# 47   0.127273  71.280258  возможность         40   8.710333      дать
# 579  0.074074  30.722751        обыск         18   8.791947  провести
#
#      VERB_freq  colloc_freq  reverse_order  LLR_rank  PMI_rank  Dice_rank  \
# 14          70            3          False      68.0      41.0       30.0
# 34          70            2          False      88.0      11.0       50.0
# 47          70            7          False      26.0      69.0       10.0
# 579         63            3          False      75.0      64.0       31.0
#
#      in_vocab
# 14       True
# 34       True
# 47       True
# 579      True

# %% [markdown]
# Получили всего четыре коллокации - <i>дать согласие</i>, <i>дать добро</i>, <i>дать возможность</i>, <i>провести обыск</i>

# %% [markdown]
# Посмотрим какие сочетания вошли в топ-100, но не вошли в словарь:

# %%
gold_stand[gold_stand['in_vocab'] == False]
# Out:
#          Dice         LLR          NOUN  NOUN_freq        PMI          VERB  \
# 23   0.140625   89.786431   компенсация         66   8.525524     выплатить
# 64   0.120000   62.605454     показание         30   8.902978          дать
# 87   0.077922   37.579985     голодовка          5  10.447299      объявить
# 101  0.073171   31.759534  доначисление         14   9.044334      оспорить
# 106  0.062500   27.674145     иркутянин          2  11.399993     выплатить
# 121  0.060606   23.415776      горсовет          6   9.862336       обязать
# 149  0.133333   63.692623    законность         36   9.014339    оспаривать
# 180  0.040000   24.240250         Ктк-р          3  10.169314    предъявить
# 187  0.119048   53.464346          знак         27   9.088340  использовать
# 192  0.133333   66.684590   предписание         22   9.392257      оспорить
# 201  0.153257  187.893826        жалоба        192   7.982630     отклонить
# 232  0.125984   80.985660    законность         36   8.676469   подтвердить
# 241  0.062500   27.674145        штрафа          2  11.399993     выплатить
# 256  0.172840   79.849846        прения         31   9.563492        пройти
# 267  0.076923   37.270436     апелляция         35   8.116382     отклонить
# 281  0.068966   28.280305     положение         30   8.199371  использовать
# 282  0.093750   55.629112   регистрация         45   8.072259      отменить
# 353  0.086022   38.484424         довод         38   8.324902        счесть
# 360  0.057692   28.115359          указ         21   8.171795      отменить
# 361  0.059406   37.097929          нота          4  10.339239    предъявить
# 435  0.061538   27.609121     неустойка          2  11.376909      взыскать
# 439  0.076923   34.934944          свет          8   9.809869          дать
# 600  0.081081   39.090627        киллер          4  10.809869          дать
# 651  0.074074   29.615298  незаконность         24   8.521299      доказать
# 819  0.044776   32.106926      повестка          7   9.143112      получить
#
#      VERB_freq  colloc_freq  reverse_order  LLR_rank  PMI_rank  Dice_rank  \
# 23          62            9          False      22.0      73.0        7.0
# 64          70            6          False      32.0      61.0       12.0
# 87          72            3          False      55.0      19.0       27.0
# 101         68            3          False      74.0      55.0       32.0
# 106         62            2          False      86.0       8.0       41.0
# 121         60            2          False      99.0      30.0       46.0
# 149         54            6          False      30.0      56.0        8.0
# 180         97            2          False      98.0      25.0       74.0
# 187         57            5          False      40.0      53.0       13.0
# 192         68            6          False      29.0      43.0        8.0
# 201         69           20          False       8.0     100.0        5.0
# 232         91            8          False      23.0      70.0       11.0
# 241         62            2          False      86.0       8.0       41.0
# 256         50            7          False      24.0      38.0        2.0
# 267         69            4          False      56.0      92.0       29.0
# 281         57            3          False      83.0      88.0       34.0
# 282         83            6          False      39.0      93.0       18.0
# 353         55            4          False      54.0      84.0       19.0
# 360         83            3          False      84.0      90.0       48.0
# 361         97            3          False      57.0      23.0       47.0
# 435         63            2          False      87.0       9.0       43.0
# 439         70            3          False      60.0      32.0       29.0
# 600         70            3          False      53.0      14.0       25.0
# 651         57            3          False      78.0      74.0       31.0
# 819        127            3          False      73.0      50.0       65.0
#
#      in_vocab
# 23      False
# 64      False
# 87      False
# 101     False
# 106     False
# 121     False
# 149     False
# 180     False
# 187     False
# 192     False
# 201     False
# 232     False
# 241     False
# 256     False
# 267     False
# 281     False
# 282     False
# 353     False
# 360     False
# 361     False
# 435     False
# 439     False
# 600     False
# 651     False
# 819     False

# %% [markdown]
# Коллокации: <i>выплатить компенсацию</i> (устойчивое, специфичное - характерно для конкретной (юридической) сферы), <i>дать показание</i> (устойчивое, некомпозициональное), <i>объявить голодовку</i> (устойчивое, некомпозициональное), <i>счесть довод</i> (устойчивое, некомпозициональное), <i>предъявить ноту</i> (устойчивое, некомпозициональное -  не могу вспомнить конструкцию, в которой <i>нота</i> употреблялось бы в таком же значении), <i>дать свет</i> (устойчивое, некомпозициональное), <i>получить повестку</i> (устойчивое, специфичное - характерно для конкретной (юридической) сферы)

# %%
needed_ids = [14, 34, 47, 579, 23, 64, 87, 361, 439, 819]
gs = gold_stand.filter(items=needed_ids, axis=0)

# %%
gs
# Out:
#          Dice        LLR         NOUN  NOUN_freq        PMI        VERB  \
# 14   0.075000  33.597682     согласие         10   9.487940        дать
# 34   0.055556  27.181366        добро          2  11.224906        дать
# 47   0.127273  71.280258  возможность         40   8.710333        дать
# 579  0.074074  30.722751        обыск         18   8.791947    провести
# 23   0.140625  89.786431  компенсация         66   8.525524   выплатить
# 64   0.120000  62.605454    показание         30   8.902978        дать
# 87   0.077922  37.579985    голодовка          5  10.447299    объявить
# 361  0.059406  37.097929         нота          4  10.339239  предъявить
# 439  0.076923  34.934944         свет          8   9.809869        дать
# 819  0.044776  32.106926     повестка          7   9.143112    получить
#
#      VERB_freq  colloc_freq  reverse_order  LLR_rank  PMI_rank  Dice_rank  \
# 14          70            3          False      68.0      41.0       30.0
# 34          70            2          False      88.0      11.0       50.0
# 47          70            7          False      26.0      69.0       10.0
# 579         63            3          False      75.0      64.0       31.0
# 23          62            9          False      22.0      73.0        7.0
# 64          70            6          False      32.0      61.0       12.0
# 87          72            3          False      55.0      19.0       27.0
# 361         97            3          False      57.0      23.0       47.0
# 439         70            3          False      60.0      32.0       29.0
# 819        127            3          False      73.0      50.0       65.0
#
#      in_vocab
# 14       True
# 34       True
# 47       True
# 579      True
# 23      False
# 64      False
# 87      False
# 361     False
# 439     False
# 819     False

# %% [markdown]
# Введём для данного набора коллокаций собственное ранжирование и при помощи коэффициента корреляции Спирмена сравним его с ранжированием по PMI, LLR и Dice:

# %% [markdown]
# Первое - самое некомпозициональное:
#
# Предъявить ноту
#
# Далее - сочетания с глаголом "дать", от метафорических к (конечно же, относительно) более конкретным:
#
# Дать добро
#
# Дать возможность
#
# Дать свет
#
# Дать согласие
#
# Дать показание
#
# Далее - оставшееся некомпозициональное:
#
# Объявить голодовку
#
# Далее - словосочетания с конкретной семантикой, сортируем по специфичности:
#
# Провести обыск
#
# Выплатить компенсацию
#
# Получить повестку

# %%
intuitive_ranks = [2, 7, 1, 4, 5, 10, 6, 8, 3, 9]
gs['Intuitive rank'] = intuitive_ranks

# %% [markdown]
# Сравним это ранжирование с ранжированием по PMI:

# %%
gs['Intuitive rank'].corr(gs['PMI'], method='spearman')
# Out:
# 0.2727272727272727

# %% [markdown]
# С ранжированием по LLR:

# %%
gs['Intuitive rank'].corr(gs['LLR'], method='spearman')
# Out:
# -0.10303030303030303

# %% [markdown]
# С ранжированием по Dice:

# %%
gs['Intuitive rank'].corr(gs['Dice'], method='spearman')
# Out:
# -0.3696969696969697

# %% [markdown]
# Получаем, что лучше всего с нашей лингвистической интуицией совпадает ранжирование по PMI

# %% [markdown]
# Отсортируем по Dice:

# %%
gs.sort_values(by='Dice', ascending=False)
# Out:
#          Dice        LLR         NOUN  NOUN_freq        PMI        VERB  \
# 23   0.140625  89.786431  компенсация         66   8.525524   выплатить
# 47   0.127273  71.280258  возможность         40   8.710333        дать
# 64   0.120000  62.605454    показание         30   8.902978        дать
# 87   0.077922  37.579985    голодовка          5  10.447299    объявить
# 439  0.076923  34.934944         свет          8   9.809869        дать
# 14   0.075000  33.597682     согласие         10   9.487940        дать
# 579  0.074074  30.722751        обыск         18   8.791947    провести
# 361  0.059406  37.097929         нота          4  10.339239  предъявить
# 34   0.055556  27.181366        добро          2  11.224906        дать
# 819  0.044776  32.106926     повестка          7   9.143112    получить
#
#      VERB_freq  colloc_freq  reverse_order  LLR_rank  PMI_rank  Dice_rank  \
# 23          62            9          False      22.0      73.0        7.0
# 47          70            7          False      26.0      69.0       10.0
# 64          70            6          False      32.0      61.0       12.0
# 87          72            3          False      55.0      19.0       27.0
# 439         70            3          False      60.0      32.0       29.0
# 14          70            3          False      68.0      41.0       30.0
# 579         63            3          False      75.0      64.0       31.0
# 361         97            3          False      57.0      23.0       47.0
# 34          70            2          False      88.0      11.0       50.0
# 819        127            3          False      73.0      50.0       65.0
#
#      in_vocab
# 23      False
# 47       True
# 64      False
# 87      False
# 439     False
# 14       True
# 579      True
# 361     False
# 34       True
# 819     False

# %% [markdown]
# Заметим, что Dice сильно зависит от частоты словосочетания, поэтому некоторые некомпозициональные конструкции оказываются в конце топа.

# %% [markdown]
# Отсортируем по Log-Likelihood Ratio:

# %%
gs.sort_values(by='LLR', ascending=False)
# Out:
#          Dice        LLR         NOUN  NOUN_freq        PMI        VERB  \
# 23   0.140625  89.786431  компенсация         66   8.525524   выплатить
# 47   0.127273  71.280258  возможность         40   8.710333        дать
# 64   0.120000  62.605454    показание         30   8.902978        дать
# 87   0.077922  37.579985    голодовка          5  10.447299    объявить
# 361  0.059406  37.097929         нота          4  10.339239  предъявить
# 439  0.076923  34.934944         свет          8   9.809869        дать
# 14   0.075000  33.597682     согласие         10   9.487940        дать
# 819  0.044776  32.106926     повестка          7   9.143112    получить
# 579  0.074074  30.722751        обыск         18   8.791947    провести
# 34   0.055556  27.181366        добро          2  11.224906        дать
#
#      VERB_freq  colloc_freq  reverse_order  LLR_rank  PMI_rank  Dice_rank  \
# 23          62            9          False      22.0      73.0        7.0
# 47          70            7          False      26.0      69.0       10.0
# 64          70            6          False      32.0      61.0       12.0
# 87          72            3          False      55.0      19.0       27.0
# 361         97            3          False      57.0      23.0       47.0
# 439         70            3          False      60.0      32.0       29.0
# 14          70            3          False      68.0      41.0       30.0
# 819        127            3          False      73.0      50.0       65.0
# 579         63            3          False      75.0      64.0       31.0
# 34          70            2          False      88.0      11.0       50.0
#
#      in_vocab
# 23      False
# 47       True
# 64      False
# 87      False
# 361     False
# 439     False
# 14       True
# 819     False
# 579      True
# 34       True

# %% [markdown]
# Заметим, что ранжирование по Log-Likelihood Ratio в данном случае почти аналогично ранжированию по Dice и, соответственно, страдает от тех же самых проблем.

# %% [markdown]
# Отсортируем по PMI:

# %%
gs.sort_values(by='PMI', ascending=False)
# Out:
#          Dice        LLR         NOUN  NOUN_freq        PMI        VERB  \
# 34   0.055556  27.181366        добро          2  11.224906        дать
# 87   0.077922  37.579985    голодовка          5  10.447299    объявить
# 361  0.059406  37.097929         нота          4  10.339239  предъявить
# 439  0.076923  34.934944         свет          8   9.809869        дать
# 14   0.075000  33.597682     согласие         10   9.487940        дать
# 819  0.044776  32.106926     повестка          7   9.143112    получить
# 64   0.120000  62.605454    показание         30   8.902978        дать
# 579  0.074074  30.722751        обыск         18   8.791947    провести
# 47   0.127273  71.280258  возможность         40   8.710333        дать
# 23   0.140625  89.786431  компенсация         66   8.525524   выплатить
#
#      VERB_freq  colloc_freq  reverse_order  LLR_rank  PMI_rank  Dice_rank  \
# 34          70            2          False      88.0      11.0       50.0
# 87          72            3          False      55.0      19.0       27.0
# 361         97            3          False      57.0      23.0       47.0
# 439         70            3          False      60.0      32.0       29.0
# 14          70            3          False      68.0      41.0       30.0
# 819        127            3          False      73.0      50.0       65.0
# 64          70            6          False      32.0      61.0       12.0
# 579         63            3          False      75.0      64.0       31.0
# 47          70            7          False      26.0      69.0       10.0
# 23          62            9          False      22.0      73.0        7.0
#
#      in_vocab
# 34       True
# 87      False
# 361     False
# 439     False
# 14       True
# 819     False
# 64      False
# 579      True
# 47       True
# 23      False

# %% [markdown]
# Заметим, что PMI не выводит в топ коллокации, состояшие из частоупотребимых самих по себе слов (<i>дать возможность</i>)
